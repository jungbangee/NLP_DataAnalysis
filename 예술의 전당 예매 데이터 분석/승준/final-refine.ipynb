# %% [markdown]
# # 최종가공

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = '/content/drive/MyDrive/멋사/mid project/'

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(DATA_PATH + 'first_refine.csv')
df.head()
# Out:
#                          공연이름  공연장소        공연날짜    공연시간  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀  2023-03-21  193000  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀  2023-03-21  193000  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀  2023-03-21  193000  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀  2023-03-21  193000  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀  2023-03-21  193000  합창
#
#                                  가격대      구매날짜    구매시간        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원  20230308   70000       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원  20230221  190000       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원  20230228   10000       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원  20230226  100000       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원  20230320  230000  골드회원 할인40%  18000.0
#
#   회원등급  나이  성별 거주지  환불여부    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0   무료  50   1  경기     0  2505.0  2481.0  24.0  0.0    0.0
# ...

# %%
org_df = df.copy()

# %% [markdown]
# - object 타입인 공연날짜를 datetime으로 변경

# %%
org_df['공연날짜'] = pd.to_datetime(org_df['공연날짜'])
org_df.head()
# Out:
#                          공연이름  공연장소       공연날짜    공연시간  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
#
#                                  가격대      구매날짜    구매시간        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원  20230308   70000       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원  20230221  190000       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원  20230228   10000       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원  20230226  100000       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원  20230320  230000  골드회원 할인40%  18000.0
#
#   회원등급  나이  성별 거주지  환불여부    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0   무료  50   1  경기     0  2505.0  2481.0  24.0  0.0    0.0
# ...

# %% [markdown]
# - 공연시간을 포매팅해서 공연시간_formatted에 삽입

# %%
org_df['공연시간_str'] = org_df['공연시간'].astype(str).str.zfill(6)  # 6자리로 맞추기
org_df['공연시간_formatted'] = org_df['공연시간_str'].str[:2] + ':' + org_df['공연시간_str'].str[2:4] + ':' + org_df['공연시간_str'].str[4:]
org_df.head()
# Out:
#                          공연이름  공연장소       공연날짜    공연시간  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
#
#                                  가격대      구매날짜    구매시간        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원  20230308   70000       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원  20230221  190000       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원  20230228   10000       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원  20230226  100000       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원  20230320  230000  골드회원 할인40%  18000.0
#
#    ... 성별  거주지  환불여부    총판매석   일반판매석  장애인석  OP석  판매유보석  공연시간_str  \
# 0  ...  1   경기     0  2505.0  2481.0  24.0  0.0    0.0    193000
# ...

# %%
org_df['공연날짜'] = pd.to_datetime(org_df['공연날짜'].dt.date.astype(str) + ' ' + org_df['공연시간_formatted'])
org_df.head()
# Out:
#                          공연이름  공연장소                공연날짜    공연시간  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  193000  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  193000  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  193000  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  193000  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  193000  합창
#
#                                  가격대      구매날짜    구매시간        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원  20230308   70000       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원  20230221  190000       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원  20230228   10000       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원  20230226  100000       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원  20230320  230000  골드회원 할인40%  18000.0
#
#    ... 성별  거주지  환불여부    총판매석   일반판매석  장애인석  OP석  판매유보석  공연시간_str  \
# ...

# %%
org_df = org_df.drop(columns=['공연시간_str', '공연시간_formatted', '공연시간'])

# %%
org_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대      구매날짜    구매시간        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원  20230308   70000       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원  20230221  190000       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원  20230228   10000       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원  20230226  100000       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원  20230320  230000  골드회원 할인40%  18000.0
#
#   회원등급  나이  성별 거주지  환불여부    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0   무료  50   1  경기     0  2505.0  2481.0  24.0  0.0    0.0
# ...

# %% [markdown]
# # 구매날짜, 구매시간도 똑같이 진행

# %%
org_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3611140 entries, 0 to 3611139
# Data columns (total 19 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   공연이름    object
#  1   공연장소    object
#  2   공연날짜    datetime64[ns]
#  3   장르      object
#  4   가격대     object
#  5   구매날짜    int64
#  6   구매시간    int64
#  7   할인정보    object
#  8   구매가격    float64
#  9   회원등급    object
#  10  나이      int64
#  11  성별      int64
#  12  거주지     object
#  13  환불여부    int64
#  14  총판매석    float64
#  15  일반판매석   float64
#  16  장애인석    float64
#  17  OP석     float64
#  18  판매유보석   float64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(7)
# memory usage: 523.5+ MB

# %%
org_df['구매날짜'] = pd.to_datetime(org_df['구매날짜'], format='%Y%m%d', errors='coerce')
org_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대       구매날짜    구매시간        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원 2023-03-08   70000       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원 2023-02-21  190000       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원 2023-02-28   10000       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원 2023-02-26  100000       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원 2023-03-20  230000  골드회원 할인40%  18000.0
#
#   회원등급  나이  성별 거주지  환불여부    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0   무료  50   1  경기     0  2505.0  2481.0  24.0  0.0    0.0
# ...

# %%
org_df['구매시간_str'] = org_df['구매시간'].astype(str).str.zfill(6)  # 6자리로 맞추기
org_df['구매시간_formatted'] = org_df['구매시간_str'].str[:2] + ':' + org_df['구매시간_str'].str[2:4] + ':' + org_df['구매시간_str'].str[4:]
org_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대       구매날짜    구매시간        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원 2023-03-08   70000       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원 2023-02-21  190000       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원 2023-02-28   10000       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원 2023-02-26  100000       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원 2023-03-20  230000  골드회원 할인40%  18000.0
#
#   회원등급  ...  성별  거주지 환불여부    총판매석   일반판매석  장애인석  OP석  판매유보석  구매시간_str  \
# ...

# %%
org_df['구매날짜'] = pd.to_datetime(org_df['구매날짜'].dt.date.astype(str) + ' ' + org_df['구매시간_formatted'])
org_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대                구매날짜    구매시간        할인정보  \
# 0  R석 30000원 / S석 20000원 / A석 10000원 2023-03-08 07:00:00   70000       기타 할인
# 1  R석 30000원 / S석 20000원 / A석 10000원 2023-02-21 19:00:00  190000       기타 할인
# 2  R석 30000원 / S석 20000원 / A석 10000원 2023-02-28 01:00:00   10000       기타 할인
# 3  R석 30000원 / S석 20000원 / A석 10000원 2023-02-26 10:00:00  100000       기타 할인
# 4  R석 30000원 / S석 20000원 / A석 10000원 2023-03-20 23:00:00  230000  골드회원 할인40%
#
#       구매가격 회원등급  ...  성별  거주지 환불여부    총판매석   일반판매석  장애인석  OP석  판매유보석  \
# ...

# %%
org_df = org_df.drop(columns=['구매시간_str', '구매시간_formatted', '구매시간'])
org_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대                구매날짜        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원 2023-03-08 07:00:00       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원 2023-02-21 19:00:00       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원 2023-02-28 01:00:00       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원 2023-02-26 10:00:00       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원 2023-03-20 23:00:00  골드회원 할인40%  18000.0
#
#   회원등급  나이  성별 거주지  환불여부    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0   무료  50   1  경기     0  2505.0  2481.0  24.0  0.0    0.0
# ...

# %%
org_df['총판매석'] = org_df['총판매석'].fillna(0).astype(int)
org_df['일반판매석'] = org_df['일반판매석'].fillna(0).astype(int)
org_df['장애인석'] = org_df['장애인석'].fillna(0).astype(int)
org_df['OP석'] = org_df['OP석'].fillna(0).astype(int)
org_df['판매유보석'] = org_df['판매유보석'].fillna(0).astype(int)
org_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3611140 entries, 0 to 3611139
# Data columns (total 18 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   공연이름    object
#  1   공연장소    object
#  2   공연날짜    datetime64[ns]
#  3   장르      object
#  4   가격대     object
#  5   구매날짜    datetime64[ns]
#  6   할인정보    object
#  7   구매가격    float64
#  8   회원등급    object
#  9   나이      int64
#  10  성별      int64
#  11  거주지     object
#  12  환불여부    int64
#  13  총판매석    int64
#  14  일반판매석   int64
#  15  장애인석    int64
#  16  OP석     int64
#  17  판매유보석   int64
# dtypes: datetime64[ns](2), float64(1), int64(8), object(7)
# memory usage: 495.9+ MB

# %%
org_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대                구매날짜        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원 2023-03-08 07:00:00       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원 2023-02-21 19:00:00       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원 2023-02-28 01:00:00       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원 2023-02-26 10:00:00       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원 2023-03-20 23:00:00  골드회원 할인40%  18000.0
#
#   회원등급  나이  성별 거주지  환불여부  총판매석  일반판매석  장애인석  OP석  판매유보석
# 0   무료  50   1  경기     0  2505   2481    24    0      0
# ...

# %%
org_df = org_df.drop(columns=['OP석'])

# %%
org_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대                구매날짜        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원 2023-03-08 07:00:00       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원 2023-02-21 19:00:00       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원 2023-02-28 01:00:00       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원 2023-02-26 10:00:00       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원 2023-03-20 23:00:00  골드회원 할인40%  18000.0
#
#   회원등급  나이  성별 거주지  환불여부  총판매석  일반판매석  장애인석  판매유보석
# 0   무료  50   1  경기     0  2505   2481    24      0
# ...

# %%
# file_save = DATA_PATH + 'refine_result2.csv'
# org_df.to_csv(file_save, index=True)

# %% [markdown]
# ### 평가 바뀐사항
# - 강사님 평가 30%, 서은강사님 평가 30%, 수강생 40%
# - 조별로 평가할 예정
# - 조별로 엑셀파일에 작성해서 평가함
# - 엑셀파일 링크는 조장에게 디엠으로 배포, 조장은 각자 조원에게 디엠으로 보내야함

# %% [markdown]
# ### 추가할것
# - 인덱스번호로 id값
# - 성별값 MF로 회귀
#
# ### 삭제할것
# - 구매날짜
# - 총판매석 제외 나머지 좌석값

# %%
# 다시 시작

# %%
org_df = org_df.drop(columns=['일반판매석', '장애인석', '판매유보석'])

# %%
org_id_df = org_df.copy()
org_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대                구매날짜        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원 2023-03-08 07:00:00       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원 2023-02-21 19:00:00       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원 2023-02-28 01:00:00       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원 2023-02-26 10:00:00       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원 2023-03-20 23:00:00  골드회원 할인40%  18000.0
#
#   회원등급  나이  성별 거주지  환불여부  총판매석
# 0   무료  50   1  경기     0  2505
# 1   블루  60   0  서울     0  2505
# 2   무료  60   0  서울     0  2505
# ...

# %%
# 각 인덱스 번호를 새로운 컬럼으로 생성
org_id_df['id'] = org_id_df.index
org_id_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대                구매날짜        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원 2023-03-08 07:00:00       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원 2023-02-21 19:00:00       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원 2023-02-28 01:00:00       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원 2023-02-26 10:00:00       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원 2023-03-20 23:00:00  골드회원 할인40%  18000.0
#
#   회원등급  나이  성별 거주지  환불여부  총판매석  id
# 0   무료  50   1  경기     0  2505   0
# 1   블루  60   0  서울     0  2505   1
# ...

# %%
# 구매날짜 삭제
org_id_df = org_id_df.drop(columns=['구매날짜'])
org_id_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대        할인정보     구매가격 회원등급  나이  성별 거주지  \
# 0  R석 30000원 / S석 20000원 / A석 10000원       기타 할인  24000.0   무료  50   1  경기
# 1  R석 30000원 / S석 20000원 / A석 10000원       기타 할인  10000.0   블루  60   0  서울
# 2  R석 30000원 / S석 20000원 / A석 10000원       기타 할인   8000.0   무료  60   0  서울
# 3  R석 30000원 / S석 20000원 / A석 10000원       기타 할인  24000.0   무료  40   0  서울
# 4  R석 30000원 / S석 20000원 / A석 10000원  골드회원 할인40%  18000.0   골드  60   1  서울
#
#    환불여부  총판매석  id
# 0     0  2505   0
# 1     0  2505   1
# 2     0  2505   2
# 3     0  2505   3
# 4     0  2505   4

# %%
# prompt: 성별 컬럼의 값들을 1은 F, 0은 M으로 바꿔줘

# 성별 컬럼의 값을 1은 'F', 0은 'M'으로 변경
org_id_df['성별'] = org_id_df['성별'].map({1: 'F', 0: 'M'})

org_id_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대        할인정보     구매가격 회원등급  나이 성별 거주지  \
# 0  R석 30000원 / S석 20000원 / A석 10000원       기타 할인  24000.0   무료  50  F  경기
# 1  R석 30000원 / S석 20000원 / A석 10000원       기타 할인  10000.0   블루  60  M  서울
# 2  R석 30000원 / S석 20000원 / A석 10000원       기타 할인   8000.0   무료  60  M  서울
# 3  R석 30000원 / S석 20000원 / A석 10000원       기타 할인  24000.0   무료  40  M  서울
# 4  R석 30000원 / S석 20000원 / A석 10000원  골드회원 할인40%  18000.0   골드  60  F  서울
#
#    환불여부  총판매석  id
# 0     0  2505   0
# 1     0  2505   1
# 2     0  2505   2
# 3     0  2505   3
# 4     0  2505   4

# %%
org_id_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3611140 entries, 0 to 3611139
# Data columns (total 14 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   공연이름    object
#  1   공연장소    object
#  2   공연날짜    datetime64[ns]
#  3   장르      object
#  4   가격대     object
#  5   할인정보    object
#  6   구매가격    float64
#  7   회원등급    object
#  8   나이      int64
#  9   성별      object
#  10  거주지     object
#  11  환불여부    int64
#  12  총판매석    int64
#  13  id      int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(8)
# memory usage: 385.7+ MB

# %%
# id 컬럼 이름 변경, 대문자로
org_id_df = org_id_df.rename(columns={'id': 'ID'})
org_id_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대        할인정보     구매가격 회원등급  나이 성별 거주지  \
# 0  R석 30000원 / S석 20000원 / A석 10000원       기타 할인  24000.0   무료  50  F  경기
# 1  R석 30000원 / S석 20000원 / A석 10000원       기타 할인  10000.0   블루  60  M  서울
# 2  R석 30000원 / S석 20000원 / A석 10000원       기타 할인   8000.0   무료  60  M  서울
# 3  R석 30000원 / S석 20000원 / A석 10000원       기타 할인  24000.0   무료  40  M  서울
# 4  R석 30000원 / S석 20000원 / A석 10000원  골드회원 할인40%  18000.0   골드  60  F  서울
#
#    환불여부  총판매석  ID
# 0     0  2505   0
# 1     0  2505   1
# 2     0  2505   2
# 3     0  2505   3
# 4     0  2505   4

# %%
org_id_df['구매가격'] = org_df['구매가격'].fillna(0).astype(int)
org_id_df.head()
# Out:
#                          공연이름  공연장소                공연날짜  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00  합창
#
#                                  가격대        할인정보   구매가격 회원등급  나이 성별 거주지  환불여부  \
# 0  R석 30000원 / S석 20000원 / A석 10000원       기타 할인  24000   무료  50  F  경기     0
# 1  R석 30000원 / S석 20000원 / A석 10000원       기타 할인  10000   블루  60  M  서울     0
# 2  R석 30000원 / S석 20000원 / A석 10000원       기타 할인   8000   무료  60  M  서울     0
# 3  R석 30000원 / S석 20000원 / A석 10000원       기타 할인  24000   무료  40  M  서울     0
# 4  R석 30000원 / S석 20000원 / A석 10000원  골드회원 할인40%  18000   골드  60  F  서울     0
#
#    총판매석  ID
# 0  2505   0
# 1  2505   1
# 2  2505   2
# 3  2505   3
# 4  2505   4

# %%
# file_save = DATA_PATH + 'refine.csv'
# org_id_df.to_csv(file_save, index=False)

# %%
# prompt: 공연이름에 '취소'가 들어간 행 검색

# '공연이름' 열에서 '취소'가 포함된 행을 검색합니다.
canceled_performances = org_id_df[org_id_df['공연이름'].str.contains('취소')]

# 검색된 행을 출력합니다.
canceled_performances
# Out:
#                                     공연이름    공연장소                공연날짜   장르  \
# 77763        [공연취소] 테너 후안 디에고 플로레즈 내한 공연    콘서트홀 2023-02-12 17:00:00  교향곡
# 77764        [공연취소] 테너 후안 디에고 플로레즈 내한 공연    콘서트홀 2023-02-12 17:00:00  교향곡
# 77765        [공연취소] 테너 후안 디에고 플로레즈 내한 공연    콘서트홀 2023-02-12 17:00:00  교향곡
# 77766        [공연취소] 테너 후안 디에고 플로레즈 내한 공연    콘서트홀 2023-02-12 17:00:00  교향곡
# 77767        [공연취소] 테너 후안 디에고 플로레즈 내한 공연    콘서트홀 2023-02-12 17:00:00  교향곡
# ...                                  ...     ...                 ...  ...
# 1444339  [공연취소] 2020 예술의전당 아티스트 라운지 (7월)  IBK챔버홀 2020-07-15 20:00:00  실내악
# 1444340  [공연취소] 2020 예술의전당 아티스트 라운지 (7월)  IBK챔버홀 2020-07-15 20:00:00  실내악
# 1444341  [공연취소] 2020 예술의전당 아티스트 라운지 (7월)  IBK챔버홀 2020-07-15 20:00:00  실내악
# 1444342  [공연취소] 2020 예술의전당 아티스트 라운지 (7월)  IBK챔버홀 2020-07-15 20:00:00  실내악
# 1444343  [공연취소] 2020 예술의전당 아티스트 라운지 (7월)  IBK챔버홀 2020-07-15 20:00:00  실내악
#
#                                                가격대       할인정보    구매가격  회원등급  \
# ...

# %%
# prompt: canceled_performances 행을 org_id_df에서 삭제

# 'canceled_performances' 행을 'org_id_df'에서 삭제합니다.
org_id_df = org_id_df.drop(canceled_performances.index)
org_id_df
# Out:
#                                공연이름  공연장소                공연날짜   장르  \
# 0        국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00   합창
# 1        국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00   합창
# 2        국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00   합창
# 3        국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00   합창
# 4        국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21 19:30:00   합창
# ...                             ...   ...                 ...  ...
# 3611135      로열 콘세르트허바우 오케스트라(4.23)  콘서트홀 2015-04-23 20:00:00  클래식
# 3611136      로열 콘세르트허바우 오케스트라(4.23)  콘서트홀 2015-04-23 20:00:00  클래식
# 3611137      로열 콘세르트허바우 오케스트라(4.23)  콘서트홀 2015-04-23 20:00:00  클래식
# 3611138      로열 콘세르트허바우 오케스트라(4.23)  콘서트홀 2015-04-23 20:00:00  클래식
# 3611139      로열 콘세르트허바우 오케스트라(4.23)  콘서트홀 2015-04-23 20:00:00  클래식
#
#                                                     가격대        할인정보    구매가격  \
# 0                     R석 30000원 / S석 20000원 / A석 10000원       기타 할인   24000
# ...
